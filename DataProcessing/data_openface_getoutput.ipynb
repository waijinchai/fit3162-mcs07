# %% [markdown]
# ### Run this code to feed folders containing MP4 videos into OpenFace
#
# #####  Folder structure
# - DataProcessing\this_script
# - DataProcessing\videos\ -> where the folder of videos are located
# - DataProcessing\videos_openface_output -> where you can find the Openface output

# %%
import os
import subprocess

# Directory of this project
base_path = r"C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07"

# Relative paths to video folders and the output folder
s07_input_video_folder_rel_path = [
    r'DataProcessing\videos\S07\S07\100(Anxiety)\Part1',
    r'DataProcessing\videos\S07\S07\100(Anxiety)\Part2',
    r'DataProcessing\videos\S07\S07\100(Anxiety)\Part3',
    r'DataProcessing\videos\S07\S07\200(Mild)\Part1',
    r'DataProcessing\videos\S07\S07\200(Mild)\Part2',
    r'DataProcessing\videos\S07\S07\200(Mild)\Part3',
    r'DataProcessing\videos\S07\S07\300(Moderate)\Part1',
    r'DataProcessing\videos\S07\S07\300(Moderate)\Part2',
    r'DataProcessing\videos\S07\S07\400(Severe)\Part1',
    r'DataProcessing\videos\S07\S07\400(Severe)\Part2',
    r'DataProcessing\videos\S07\S07\400(Severe)\Part3',
]

output_folder = os.path.join(base_path, r"DataProcessing\videos_openface_output\S07_Output")
path_to_featureextractionexe = os.path.join(base_path, r"OpenFace\OpenFace_2.2.0_win_x64\FeatureExtraction.exe")

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Process each directory
for folder in s07_input_video_folder_rel_path:
    full_folder_path = os.path.join(base_path, folder)
    print("Processing videos in:", full_folder_path)
    
    if os.path.exists(full_folder_path):
        # List all .mp4 files in the directory
        video_files = [file for file in os.listdir(full_folder_path) if file.endswith('.mp4')]
        
        for video_file in video_files:
            video_path = os.path.join(full_folder_path, video_file)
            output_file_path = os.path.join(output_folder, f"{os.path.splitext(video_file)[0]}.csv")
            
            # Constructing the command to run FeatureExtraction
            command = [
                path_to_featureextractionexe,
                "-f", video_path,
                "-out_dir", output_folder,
                "-of", output_file_path
            ]
            
            # Execute the command
            try:
                subprocess.run(command, check=True)
                print(f"Processed {video_file} successfully.")
            except subprocess.CalledProcessError as e:
                print(f"Failed to process {video_file}. Error: {e}")
    else:
        print(f"Directory not found: {full_folder_path}")

print("All videos processed.")
# Out:
# Processing videos in: C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07\DataProcessing\videos\S07\S07\100(Anxiety)\Part1
# Processed S07_1001-1.mp4 successfully.
# Processed S07_1001-2.mp4 successfully.
# Processed S07_1001-3.mp4 successfully.
# Processed S07_1001-4.mp4 successfully.
# Processed S07_1001-5.mp4 successfully.
# Processed S07_1001-6.mp4 successfully.
# Processed S07_1001-7.mp4 successfully.
# Processed S07_1001-8.mp4 successfully.
# Processing videos in: C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07\DataProcessing\videos\S07\S07\100(Anxiety)\Part2
# Processed S07_1002-1.mp4 successfully.
# Processed S07_1002-2.mp4 successfully.
# Processed S07_1002-3.mp4 successfully.
# Processed S07_1002-4.mp4 successfully.
# Processed S07_1002-5.mp4 successfully.
# Processed S07_1002-6.mp4 successfully.
# Processed S07_1002-7.mp4 successfully.
# Processed S07_1002-8.mp4 successfully.
# Processing videos in: C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07\DataProcessing\videos\S07\S07\100(Anxiety)\Part3
# Processed S07_1003-1.mp4 successfully.
# Processed S07_1003-2.mp4 successfully.
# Processed S07_1003-3.mp4 successfully.
# Processed S07_1003-4.mp4 successfully.
# Processed S07_1003-5.mp4 successfully.
# Processed S07_1003-6.mp4 successfully.
# Processed S07_1003-7.mp4 successfully.
# Processed S07_1003-8.mp4 successfully.
# Processed S07_1003-9.mp4 successfully.
# Processing videos in: C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07\DataProcessing\videos\S07\S07\200(Mild)\Part1
# Processed S07_2001-1.mp4 successfully.
# Processed S07_2001-2.mp4 successfully.
# Processed S07_2001-3.mp4 successfully.
# Processed S07_2001-4.mp4 successfully.
# Processed S07_2001-5.mp4 successfully.
# Processed S07_2001-6.mp4 successfully.
# Processed S07_2001-7.mp4 successfully.
# Processed S07_2001-8.mp4 successfully.
# Processing videos in: C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07\DataProcessing\videos\S07\S07\200(Mild)\Part2
# Processed S07_2002-1.mp4 successfully.
# Processed S07_2002-2.mp4 successfully.
# Processed S07_2002-3.mp4 successfully.
# Processed S07_2002-4.mp4 successfully.
# Processed S07_2002-5.mp4 successfully.
# Processed S07_2002-6.mp4 successfully.
# Processed S07_2002-7.mp4 successfully.
# Processed S07_2002-8.mp4 successfully.
# Processing videos in: C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07\DataProcessing\videos\S07\S07\200(Mild)\Part3
# Processed S07_2003-01.mp4 successfully.
# Processed S07_2003-02.mp4 successfully.
# Processed S07_2003-03.mp4 successfully.
# Processed S07_2003-04.mp4 successfully.
# Processed S07_2003-05.mp4 successfully.
# Processed S07_2003-06.mp4 successfully.
# Processed S07_2003-07.mp4 successfully.
# Processed S07_2003-08.mp4 successfully.
# Processed S07_2003-09.mp4 successfully.
# Processed S07_2003-10.mp4 successfully.
# Processed S07_2003-11.mp4 successfully.
# Processed S07_2003-12.mp4 successfully.
# Processed S07_2003-13.mp4 successfully.
# Processing videos in: C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07\DataProcessing\videos\S07\S07\300(Moderate)\Part1
# Processed S07_3001-01.mp4 successfully.
# Processed S07_3001-02.mp4 successfully.
# Processed S07_3001-03.mp4 successfully.
# Processed S07_3001-04.mp4 successfully.
# Processed S07_3001-05.mp4 successfully.
# Processed S07_3001-06.mp4 successfully.
# Processed S07_3001-07.mp4 successfully.
# Processed S07_3001-08.mp4 successfully.
# Processed S07_3001-09.mp4 successfully.
# Processed S07_3001-10.mp4 successfully.
# Processed S07_3001-11.mp4 successfully.
# Processed S07_3001-12.mp4 successfully.
# Processed S07_3001-13.mp4 successfully.
# Processed S07_3001-14.mp4 successfully.
# Processing videos in: C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07\DataProcessing\videos\S07\S07\300(Moderate)\Part2
# Processed S07_3002-1.mp4 successfully.
# Processed S07_3002-2.mp4 successfully.
# Processed S07_3002-3.mp4 successfully.
# Processed S07_3002-4.mp4 successfully.
# Processed S07_3002-5.mp4 successfully.
# Processed S07_3002-6.mp4 successfully.
# Processed S07_3002-7.mp4 successfully.
# Processed S07_3002-8.mp4 successfully.
# Processed S07_3002-9.mp4 successfully.
# Processing videos in: C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07\DataProcessing\videos\S07\S07\400(Severe)\Part1
# Processed S07_4001-01.mp4 successfully.
# Processed S07_4001-02.mp4 successfully.
# Processed S07_4001-03.mp4 successfully.
# Processed S07_4001-04.mp4 successfully.
# Processed S07_4001-05.mp4 successfully.
# Processed S07_4001-06.mp4 successfully.
# Processed S07_4001-07.mp4 successfully.
# Processed S07_4001-08.mp4 successfully.
# Processed S07_4001-09.mp4 successfully.
# Processed S07_4001-10.mp4 successfully.
# Processed S07_4001-11.mp4 successfully.
# Processed S07_4001-12.mp4 successfully.
# Processing videos in: C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07\DataProcessing\videos\S07\S07\400(Severe)\Part2
# Processed S07_4002-01.mp4 successfully.
# Processed S07_4002-02.mp4 successfully.
# Processed S07_4002-03.mp4 successfully.
# Processed S07_4002-04.mp4 successfully.
# Processed S07_4002-05.mp4 successfully.
# Processed S07_4002-06.mp4 successfully.
# Processed S07_4002-07.mp4 successfully.
# Processed S07_4002-08.mp4 successfully.
# Processed S07_4002-09.mp4 successfully.
# Processed S07_4002-10.mp4 successfully.
# Processed S07_4002-11.mp4 successfully.
# Processed S07_4002-12.mp4 successfully.
# Processed S07_4002-13.mp4 successfully.
# Processed S07_4002-14.mp4 successfully.
# Processing videos in: C:\Users\Claire Low\OneDrive\Desktop\2024\FIT3162 FYP\fyp_group_mcs7\fit3162-mcs07\DataProcessing\videos\S07\S07\400(Severe)\Part3
# Processed S07_4003-01.mp4 successfully.
# Processed S07_4003-02.mp4 successfully.
# Processed S07_4003-03.mp4 successfully.
# Processed S07_4003-04.mp4 successfully.
# Processed S07_4003-05.mp4 successfully.
# Processed S07_4003-06.mp4 successfully.
# Processed S07_4003-07.mp4 successfully.
# Processed S07_4003-08.mp4 successfully.
# Processed S07_4003-09.mp4 successfully.
# Processed S07_4003-10.mp4 successfully.
# Processed S07_4003-11.mp4 successfully.
# Processed S07_4003-12.mp4 successfully.
# Processed S07_4003-13.mp4 successfully.
# Processed S07_4003-14.mp4 successfully.
# All videos processed.
